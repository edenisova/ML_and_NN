# %%
from matplotlib import pyplot
from keras.datasets import cifar10
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Dense
from keras.layers import Flatten
import numpy as np
from keras.datasets import cifar100
import matplotlib as plt
from matplotlib.figure import Figure
from matplotlib import figure
from keras.callbacks import Callback
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import confusion_matrix, f1_score, precision_score, recall_score, accuracy_score
from scikitplot.metrics import plot_confusion_matrix
from keras.optimizers import SGD
from keras.layers import Dropout


def prep_pixels(trainX, testX):
    trainNorm = trainX.astype('float32')
    testNorm = testX.astype('float32')
    trainNorm = trainNorm / 255.0
    testNorm = testNorm / 255.0
    return trainNorm, testNorm

def define_model():
    model = Sequential()
    model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', input_shape=(32, 32, 3)))
    model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
    model.add(MaxPooling2D((2, 2)))
    model.add(Dropout(0.2))
    model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
    model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
    model.add(MaxPooling2D((2, 2)))
    model.add(Dropout(0.2))
    model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
    model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
    model.add(MaxPooling2D((2, 2)))
    model.add(Dropout(0.2))
    model.add(Flatten())
    model.add(Dense(128, activation='relu', kernel_initializer='he_uniform'))
    model.add(Dropout(0.2))
    model.add(Dense(10, activation='softmax'))
    opt = SGD(lr=0.001, momentum=0.9)
    model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
    return model

def summarize_diagnostics(history):
    pyplot.subplot(211)
    pyplot.title('Cross Entropy Loss')
    pyplot.plot(history.history['loss'], color='blue', label='train')
    pyplot.subplot(212)
    pyplot.title('Classification Accuracy')
    pyplot.plot(history.history['accuracy'], color='orange', label='train')
    
class Metrics(Callback):
    def on_train_begin(self, logs={}):
        self.val_f1s = []
        self.val_recalls = []
        self.val_precisions = []
 
    def on_epoch_end(self, epoch, logs={}):
        val_predict = (np.asarray(self.model.predict(self.validation_data[0]))).round()
        val_targ = self.validation_data[1]
        _val_f1 = f1_score(val_targ, val_predict, average='macro')
        _val_recall = recall_score(val_targ, val_predict, average='macro')
        _val_precision = precision_score(val_targ, val_predict, average='macro')
        self.val_f1s.append(_val_f1)
        self.val_recalls.append(_val_recall)
        self.val_precisions.append(_val_precision)
        print(' — val_f1: %f — val_precision: %f — val_recall %f' %(_val_f1, _val_precision, _val_recall))
        return
    
(trainX, trainY), (testX, testY) = cifar10.load_data()
trainY = to_categorical(trainY)
testY = to_categorical(testY)
trainX, testX = prep_pixels(trainX, testX)
trainX, valX, trainY, valY = train_test_split(trainX, trainY, test_size=0.25, random_state=1)
model = define_model()
metrics = Metrics()
history = model.fit(trainX, trainY, epochs=100, batch_size=64,  validation_split = 0.2, verbose=2, callbacks=[metrics])
_, acc = model.evaluate(valX, valY, verbose=2)
summarize_diagnostics(history)

model.summary()
predY = model.predict(testX)
predYClasses = predY.argmax(1)
testYClasses = testY.argmax(1)
print(accuracy_score(testYClasses, predYClasses))
print(f1_score(testYClasses, predYClasses, average='macro'))
print(recall_score(testYClasses, predYClasses, average='macro'))
print(precision_score(testYClasses, predYClasses, average='macro'))
# Out:
# Train on 30000 samples, validate on 7500 samples
# Epoch 1/100
#  - 114s - loss: 2.1871 - accuracy: 0.1824 - val_loss: 1.9400 - val_accuracy: 0.3159
# C:\Users\KatePC\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#  — val_f1: 0.006941 — val_precision: 0.079412 — val_recall 0.003629
# Epoch 2/100
#  - 114s - loss: 1.8393 - accuracy: 0.3123 - val_loss: 1.7003 - val_accuracy: 0.3712
#  — val_f1: 0.111747 — val_precision: 0.342986 — val_recall 0.068279
# Epoch 3/100
#  - 115s - loss: 1.7060 - accuracy: 0.3679 - val_loss: 1.6173 - val_accuracy: 0.4011
#  — val_f1: 0.145653 — val_precision: 0.568448 — val_recall 0.090430
# Epoch 4/100
#  - 115s - loss: 1.6211 - accuracy: 0.3989 - val_loss: 1.5260 - val_accuracy: 0.4320
#  — val_f1: 0.231799 — val_precision: 0.651793 — val_recall 0.159063
# Epoch 5/100
#  - 188s - loss: 1.5458 - accuracy: 0.4310 - val_loss: 1.4325 - val_accuracy: 0.4764
#  — val_f1: 0.301812 — val_precision: 0.757895 — val_recall 0.216001
# Epoch 6/100
#  - 183s - loss: 1.4842 - accuracy: 0.4549 - val_loss: 1.4121 - val_accuracy: 0.4809
#  — val_f1: 0.319092 — val_precision: 0.718848 — val_recall 0.229972
# Epoch 7/100
#  - 183s - loss: 1.4326 - accuracy: 0.4734 - val_loss: 1.3879 - val_accuracy: 0.4848
#  — val_f1: 0.346846 — val_precision: 0.702236 — val_recall 0.285494
# Epoch 8/100
#  - 181s - loss: 1.3866 - accuracy: 0.4929 - val_loss: 1.2980 - val_accuracy: 0.5331
#  — val_f1: 0.379550 — val_precision: 0.738169 — val_recall 0.288066
# Epoch 9/100
#  - 181s - loss: 1.3476 - accuracy: 0.5097 - val_loss: 1.2554 - val_accuracy: 0.5512
#  — val_f1: 0.401379 — val_precision: 0.772934 — val_recall 0.306630
# Epoch 10/100
#  - 182s - loss: 1.3119 - accuracy: 0.5247 - val_loss: 1.2742 - val_accuracy: 0.5420
#  — val_f1: 0.424405 — val_precision: 0.725762 — val_recall 0.342548
# Epoch 11/100
#  - 182s - loss: 1.2761 - accuracy: 0.5392 - val_loss: 1.2143 - val_accuracy: 0.5644
#  — val_f1: 0.458946 — val_precision: 0.728296 — val_recall 0.390351
# Epoch 12/100
#  - 183s - loss: 1.2393 - accuracy: 0.5513 - val_loss: 1.1883 - val_accuracy: 0.5716
#  — val_f1: 0.471526 — val_precision: 0.744293 — val_recall 0.389599
# Epoch 13/100
#  - 182s - loss: 1.2007 - accuracy: 0.5666 - val_loss: 1.1421 - val_accuracy: 0.5895
#  — val_f1: 0.500504 — val_precision: 0.746614 — val_recall 0.417891
# Epoch 14/100
#  - 182s - loss: 1.1732 - accuracy: 0.5765 - val_loss: 1.0962 - val_accuracy: 0.6024
#  — val_f1: 0.520008 — val_precision: 0.780936 — val_recall 0.428076
# Epoch 15/100
#  - 182s - loss: 1.1449 - accuracy: 0.5909 - val_loss: 1.1117 - val_accuracy: 0.6021
#  — val_f1: 0.540289 — val_precision: 0.752775 — val_recall 0.455273
# Epoch 16/100
#  - 182s - loss: 1.1192 - accuracy: 0.6012 - val_loss: 1.0363 - val_accuracy: 0.6251
#  — val_f1: 0.562765 — val_precision: 0.772898 — val_recall 0.467500
# Epoch 17/100
#  - 183s - loss: 1.0815 - accuracy: 0.6114 - val_loss: 1.0275 - val_accuracy: 0.6260
#  — val_f1: 0.570559 — val_precision: 0.765388 — val_recall 0.480090
# Epoch 18/100
#  - 182s - loss: 1.0626 - accuracy: 0.6204 - val_loss: 1.0249 - val_accuracy: 0.6329
#  — val_f1: 0.581447 — val_precision: 0.761661 — val_recall 0.496454
# Epoch 19/100
#  - 182s - loss: 1.0358 - accuracy: 0.6330 - val_loss: 1.0707 - val_accuracy: 0.6243
#  — val_f1: 0.582625 — val_precision: 0.762567 — val_recall 0.513061
# Epoch 20/100
#  - 184s - loss: 1.0066 - accuracy: 0.6376 - val_loss: 0.9536 - val_accuracy: 0.6591
#  — val_f1: 0.625896 — val_precision: 0.764655 — val_recall 0.540880
# Epoch 21/100
#  - 184s - loss: 0.9844 - accuracy: 0.6498 - val_loss: 0.9399 - val_accuracy: 0.6620
#  — val_f1: 0.611724 — val_precision: 0.780878 — val_recall 0.533618
# Epoch 22/100
#  - 183s - loss: 0.9651 - accuracy: 0.6580 - val_loss: 0.8989 - val_accuracy: 0.6789
#  — val_f1: 0.642742 — val_precision: 0.792725 — val_recall 0.557746
# Epoch 23/100
#  - 182s - loss: 0.9456 - accuracy: 0.6663 - val_loss: 0.9522 - val_accuracy: 0.6635
#  — val_f1: 0.632720 — val_precision: 0.777879 — val_recall 0.562150
# Epoch 24/100
#  - 182s - loss: 0.9289 - accuracy: 0.6712 - val_loss: 0.8966 - val_accuracy: 0.6789
#  — val_f1: 0.635548 — val_precision: 0.790848 — val_recall 0.562063
# Epoch 25/100
#  - 182s - loss: 0.9097 - accuracy: 0.6743 - val_loss: 0.8705 - val_accuracy: 0.6875
#  — val_f1: 0.657256 — val_precision: 0.790515 — val_recall 0.580562
# Epoch 26/100
#  - 137s - loss: 0.8807 - accuracy: 0.6886 - val_loss: 0.8661 - val_accuracy: 0.6891
#  — val_f1: 0.658626 — val_precision: 0.790021 — val_recall 0.589508
# Epoch 27/100
#  - 121s - loss: 0.8685 - accuracy: 0.6886 - val_loss: 0.8513 - val_accuracy: 0.6964
#  — val_f1: 0.669507 — val_precision: 0.796152 — val_recall 0.594436
# Epoch 28/100
#  - 117s - loss: 0.8475 - accuracy: 0.6998 - val_loss: 0.8199 - val_accuracy: 0.7063
#  — val_f1: 0.678388 — val_precision: 0.802372 — val_recall 0.606255
# Epoch 29/100
#  - 116s - loss: 0.8338 - accuracy: 0.7052 - val_loss: 0.8007 - val_accuracy: 0.7157
#  — val_f1: 0.689995 — val_precision: 0.801601 — val_recall 0.620076
# Epoch 30/100
#  - 116s - loss: 0.8142 - accuracy: 0.7099 - val_loss: 0.8114 - val_accuracy: 0.7117
#  — val_f1: 0.682341 — val_precision: 0.805308 — val_recall 0.617221
# Epoch 31/100
#  - 117s - loss: 0.8082 - accuracy: 0.7131 - val_loss: 0.8083 - val_accuracy: 0.7179
#  — val_f1: 0.692289 — val_precision: 0.803761 — val_recall 0.627067
# Epoch 32/100
#  - 124s - loss: 0.8001 - accuracy: 0.7175 - val_loss: 0.7954 - val_accuracy: 0.7188
#  — val_f1: 0.700533 — val_precision: 0.807749 — val_recall 0.628170
# Epoch 33/100
#  - 130s - loss: 0.7825 - accuracy: 0.7201 - val_loss: 0.7616 - val_accuracy: 0.7297
#  — val_f1: 0.710268 — val_precision: 0.809961 — val_recall 0.647508
# Epoch 34/100
#  - 120s - loss: 0.7648 - accuracy: 0.7298 - val_loss: 0.7518 - val_accuracy: 0.7328
#  — val_f1: 0.714179 — val_precision: 0.809710 — val_recall 0.649790
# Epoch 35/100
#  - 117s - loss: 0.7482 - accuracy: 0.7328 - val_loss: 0.7514 - val_accuracy: 0.7339
#  — val_f1: 0.712435 — val_precision: 0.811356 — val_recall 0.648536
# Epoch 36/100
#  - 116s - loss: 0.7311 - accuracy: 0.7397 - val_loss: 0.7553 - val_accuracy: 0.7321
#  — val_f1: 0.715296 — val_precision: 0.809676 — val_recall 0.652540
# Epoch 37/100
#  - 116s - loss: 0.7293 - accuracy: 0.7416 - val_loss: 0.7478 - val_accuracy: 0.7387
#  — val_f1: 0.720465 — val_precision: 0.816353 — val_recall 0.660472
# Epoch 38/100
#  - 116s - loss: 0.7096 - accuracy: 0.7471 - val_loss: 0.7311 - val_accuracy: 0.7396
#  — val_f1: 0.725061 — val_precision: 0.819142 — val_recall 0.664549
# Epoch 39/100
#  - 117s - loss: 0.6956 - accuracy: 0.7521 - val_loss: 0.7247 - val_accuracy: 0.7479
#  — val_f1: 0.730118 — val_precision: 0.823155 — val_recall 0.668115
# Epoch 40/100
#  - 115s - loss: 0.6889 - accuracy: 0.7543 - val_loss: 0.7819 - val_accuracy: 0.7279
#  — val_f1: 0.724439 — val_precision: 0.804488 — val_recall 0.667243
# Epoch 41/100
#  - 116s - loss: 0.6829 - accuracy: 0.7575 - val_loss: 0.7055 - val_accuracy: 0.7515
#  — val_f1: 0.740705 — val_precision: 0.820943 — val_recall 0.679288
# Epoch 42/100
#  - 117s - loss: 0.6733 - accuracy: 0.7610 - val_loss: 0.7341 - val_accuracy: 0.7445
#  — val_f1: 0.732930 — val_precision: 0.812371 — val_recall 0.676447
# Epoch 43/100
#  - 114s - loss: 0.6606 - accuracy: 0.7671 - val_loss: 0.7052 - val_accuracy: 0.7463
#  — val_f1: 0.735089 — val_precision: 0.825722 — val_recall 0.676068
# Epoch 44/100
#  - 121s - loss: 0.6506 - accuracy: 0.7663 - val_loss: 0.6826 - val_accuracy: 0.7539
#  — val_f1: 0.740020 — val_precision: 0.823279 — val_recall 0.685341
# Epoch 45/100
#  - 123s - loss: 0.6400 - accuracy: 0.7722 - val_loss: 0.6907 - val_accuracy: 0.7560
#  — val_f1: 0.747782 — val_precision: 0.813872 — val_recall 0.696274
# Epoch 46/100
#  - 118s - loss: 0.6265 - accuracy: 0.7758 - val_loss: 0.6748 - val_accuracy: 0.7608
#  — val_f1: 0.748405 — val_precision: 0.818564 — val_recall 0.695218
# Epoch 47/100
#  - 137s - loss: 0.6179 - accuracy: 0.7796 - val_loss: 0.6859 - val_accuracy: 0.7563
#  — val_f1: 0.749924 — val_precision: 0.824190 — val_recall 0.697021
# Epoch 48/100
#  - 128s - loss: 0.6071 - accuracy: 0.7858 - val_loss: 0.6688 - val_accuracy: 0.7653
#  — val_f1: 0.755694 — val_precision: 0.825483 — val_recall 0.704169
# Epoch 49/100
#  - 116s - loss: 0.5976 - accuracy: 0.7877 - val_loss: 0.6639 - val_accuracy: 0.7656
#  — val_f1: 0.763102 — val_precision: 0.831726 — val_recall 0.709623
# Epoch 50/100
#  - 117s - loss: 0.5873 - accuracy: 0.7932 - val_loss: 0.6646 - val_accuracy: 0.7629
#  — val_f1: 0.759591 — val_precision: 0.826065 — val_recall 0.708032
# Epoch 51/100
#  - 132s - loss: 0.5803 - accuracy: 0.7917 - val_loss: 0.6534 - val_accuracy: 0.7677
#  — val_f1: 0.760684 — val_precision: 0.822974 — val_recall 0.713223
# Epoch 52/100
#  - 130s - loss: 0.5761 - accuracy: 0.7949 - val_loss: 0.6690 - val_accuracy: 0.7663
#  — val_f1: 0.762160 — val_precision: 0.832365 — val_recall 0.712591
# Epoch 53/100
#  - 132s - loss: 0.5657 - accuracy: 0.7982 - val_loss: 0.7016 - val_accuracy: 0.7576
#  — val_f1: 0.755279 — val_precision: 0.811256 — val_recall 0.715506
# Epoch 54/100
#  - 130s - loss: 0.5529 - accuracy: 0.8037 - val_loss: 0.6457 - val_accuracy: 0.7703
#  — val_f1: 0.766781 — val_precision: 0.829197 — val_recall 0.719416
# Epoch 55/100
#  - 128s - loss: 0.5433 - accuracy: 0.8054 - val_loss: 0.6350 - val_accuracy: 0.7729
#  — val_f1: 0.769834 — val_precision: 0.827385 — val_recall 0.723626
# Epoch 56/100
#  - 138s - loss: 0.5345 - accuracy: 0.8096 - val_loss: 0.6664 - val_accuracy: 0.7641
#  — val_f1: 0.760157 — val_precision: 0.821270 — val_recall 0.715204
# Epoch 57/100
#  - 130s - loss: 0.5297 - accuracy: 0.8096 - val_loss: 0.6677 - val_accuracy: 0.7684
#  — val_f1: 0.758207 — val_precision: 0.819332 — val_recall 0.718456
# Epoch 58/100
#  - 149s - loss: 0.5213 - accuracy: 0.8144 - val_loss: 0.6592 - val_accuracy: 0.7691

# %%
(trainXCoarse, trainYCoarse), (testXCoarse, testYCoarse) = cifar100.load_data('coarse')
(trainXFine, trainYFine), (testXFine, testYFine) = cifar100.load_data('fine')
trainXClass = trainXFine[(trainYCoarse == 14).squeeze()]
trainYClass = trainYFine[(trainYCoarse == 14).squeeze()]
trainYClass[trainYClass==[11]] = 10
trainYClass[trainYClass==[98]] = 11
trainYClass[trainYClass==[35]] = 12
trainYClass[trainYClass==[46]] = 13
trainYClass[trainYClass==[2]] = 14
testXClass = testXFine[(testYCoarse == 14).squeeze()]
testYClass = testYFine[(testYCoarse == 14).squeeze()]
testYClass[testYClass==[11]] = 10
testYClass[testYClass==[98]] = 11
testYClass[testYClass==[35]] = 12
testYClass[testYClass==[46]] = 13
testYClass[testYClass==[2]] = 14
trainY_classes = trainY.argmax(1)
testY_classes = testY.argmax(1)
trainXClass, testXClass = prep_pixels(trainXClass, testXClass)
trainXAll = np.concatenate((trainX, trainXClass))
testXAll = np.concatenate((testX, testXClass))
trainYAll = np.concatenate((trainY_classes, trainYClass))
testYAll = np.concatenate((testY_classes, testYClass))
trainYAll = to_categorical(trainYAll)
testYAll = to_categorical(testYAll)
plt.figure.Figure(figsize=(7,7))
    
for i in range(9):
    pyplot.subplot(330 + 1 + i)
    pyplot.imshow(trainXClassv[i])
pyplot.show()

for layer in model.layers: 
    layer.trainable = False
    print('Layer ' + layer.name + ' frozen.')
    
last = model.layers[-1].output
x = Dense(1000, activation='relu')(last)
x = Dropout(0.3)(x)
x = Dense(15, activation='softmax')(x)
newModel = Model(model.input, x)
newModel.compile(optimizer=Adam(lr=0.001), loss='categorical_crossentropy', metrics=['accuracy'])
newModel.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b23265be607f> in <module>
# ----> 1 (trainXCoarse, trainYCoarse), (testXCoarse, testYCoarse) = cifar100.load_data('coarse')
#       2 (trainXFine, trainYFine), (testXFine, testYFine) = cifar100.load_data('fine')
#       3 trainXClass = trainXFine[(trainYCoarse == 14).squeeze()]
#       4 trainYClass = trainYFine[(trainYCoarse == 14).squeeze()]
#       5 trainYClass[trainYClass==[11]] = 10
#
# NameError: name 'cifar100' is not defined

# %%
trainXAll, valXClass, trainYAll, valYClass = train_test_split(trainXAll, trainYAll, test_size=0.25, random_state=1)
newMetrics = Metrics()
newHistory = newModel.fit(trainXAll, trainYAll, epochs=100, batch_size=64,  validation_split = 0.2, verbose=2, callbacks=[newMetrics])
_, acc = newModel.evaluate(valXClass, valYClass, verbose=2)
summarize_diagnostics(newHistory)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-67037a0bee8f> in <module>
# ----> 1 trainXAll, valXClass, trainYAll, valYClass = train_test_split(trainXAll, trainYAll, test_size=0.25, random_state=1)
#       2 print(train_labels_dev.shape)
#       3 newMetrics = Metrics()
#       4 newHistory = newModel.fit(trainXAll, trainYAll, epochs=100, batch_size=64,  validation_split = 0.2, verbose=2, callbacks=[newMetrics])
#       5 _, acc = newModel.evaluate(valXClass, valYClass, verbose=2)
#
# NameError: name 'train_test_split' is not defined

# %%
predYAll = new_model.predict(testXAll)
predYAllClasses = predYAll.argmax(1)
testYAll = testYAll.argmax(1)
print(accuracy_score(testYAll, predYAllClasses))
print(f1_score(testYAll, predYAllClasses, average='macro'))
print(recall_score(testYAll, predYAllClasses, average='macro'))
print(precision_score(testYAll, predYAllClasses, average='macro'))
